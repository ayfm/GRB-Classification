# %% [markdown]
# # DATA PREPROCESSING

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# add grbttools to path
import sys

sys.path.append("../")

# %%
import os
import numpy as np
import pandas as pd
from grbtools import env

# %% [markdown]
# Load GRBs with Extended Emissions

# %%
# load extended emission catalog
path_cat_grb_ee = os.path.join(env.DIR_CATALOGS, "grb_ee.xlsx")
df_ee = pd.read_excel(path_cat_grb_ee, sheet_name="ee")

# show random rows
df_ee.sample(5)
# Out:
#    catalog          name  trigger_num
# 26   FERMI  GRB080807993          NaN
# 44   SWIFT    GRB100522A          NaN
# 14   BATSE   GRB 960906-       5592.0
# 45   SWIFT    GRB110207A          NaN
# 18   BATSE     4B 931031       2611.0

# %% [markdown]
# How many EE GRBs for each catalog?

# %%
df_ee["catalog"].value_counts()
# Out:
# BATSE    19
# SWIFT    16
# FERMI    14
# Name: catalog, dtype: int64

# %% [markdown]
# ## BATSE

# %% [markdown]
# Load BATSE catalog

# %%
# load batse catalog
path_cat_batse = os.path.join(env.DIR_CATALOGS, "batse_catalog.xlsx")
df_batse = pd.read_excel(path_cat_batse, sheet_name="batsegrb")

# set trigger_num as index
df_batse.set_index("trigger_num", inplace=True)

# show random rows
df_batse.sample(5)
# Out:
#                     name      ra    dec     lii    bii  day_trigger  \
# trigger_num
# 7657         GRB 990716-  337.26 -44.61  351.87 -56.66        11375
# 5556          4B 960731-  199.53 -18.29  311.77  44.12        10295
# 3751           4B 950810   30.38   5.76  152.78 -53.00         9939
# 1695          4B 920711-  276.54  73.38  104.20  27.71         8814
# 3914          4B 951120-  136.91 -33.19  258.24   9.64        10041
#
#                      time  flux_64  flux_256  flux_1024  ...     t90  \
# trigger_num                                              ...
# 7657         51375.269840    2.789    2.5875     2.3832  ...  51.840
# 5556         50295.140891    1.584    1.2990     0.8910  ...   1.511
# 3751         49939.125098    2.486    1.9830     0.8700  ...   0.535
# 1695         48814.672923      NaN       NaN        NaN  ...     NaN
# 3914         50041.141792    0.499    0.3230     0.2690  ...  54.432
#
#                 fluence_1     fluence_2     fluence_3     fluence_4  \
# trigger_num
# 7657         1.395300e-06  1.470700e-06  3.233300e-06  2.009700e-06
# 5556         4.977300e-08  6.020600e-08  1.485700e-07  0.000000e+00
# 3751         4.861200e-09  3.265700e-08  1.903400e-07  3.814500e-07
# 1695                  NaN           NaN           NaN           NaN
# 3914         1.299100e-07  2.009000e-07  4.962500e-07  5.681100e-09
#
#                                         comments_quality  \
# trigger_num
# 7657                                                 NaN
# 5556         Data gap during burst accumulation interval
# 3751                                                 NaN
# 1695                        Limited datatypes available.
# 3914         Data gap during burst accumulation interval
#
#                                              comments_otherobs  \
# trigger_num
# 7657                                                       NaN
# 5556                                                       NaN
# 3751                                                       NaN
# 1695         Ulysses, PVO, DMS rate increase, WATCH/GRANAT,...
# 3914                                                       NaN
#
#                                               comments_general  \
# trigger_num
# 7657                                                       NaN
# 5556                                                       NaN
# 3751         Noisy background due to CYG X-1 in LAD 5; Occu...
# 1695                                                       NaN
# 3914                                                       NaN
#
#                                  comments_position  \
# trigger_num
# 7657                                           NaN
# 5556                                           NaN
# 3751                                           NaN
# 1695         Location Derived using only max rates
# 3914                                           NaN
#
#                                              comments_duration
# trigger_num
# 7657                                                       NaN
# 5556                           Data gap from T+124 to T+245 s.
# 3751                                                       NaN
# 1695         Visual duration estimate of > 110 s, using MER...
# 3914                           Data gap from T+170 to T+287 s.
#
# [5 rows x 21 columns]

# %% [markdown]
# Load redshift values for BATSE catalog

# %%
# load redshift values for batse catalog
path_cat_batse_redshift = os.path.join(env.DIR_CATALOGS, "batse_redshift.xlsx")
df_batse_redshift = pd.read_excel(path_cat_batse_redshift, sheet_name="redshift")

# set trigger_num as index
df_batse_redshift.set_index("trigger_num", inplace=True)

# show random rows
df_batse_redshift.sample(5)
# Out:
#               p256    t90       V    z          L4pi
# trigger_num
# 907           3.57  158.1  0.0386  3.9  7.340000e+52
# 2922          2.85  160.8  0.0399  4.6  8.190000e+52
# 3523         21.57   59.1  0.0208  0.7  9.210000e+51
# 1623          2.98   66.1  0.0291  2.7  2.850000e+52
# 2897          2.94   28.0  0.0178  1.3  5.440000e+51

# %% [markdown]
# Set EE flag

# %%
# add column for EE flag
df_batse["ee"] = False

# get name of BATSE GRBs with EE
batse_grbs_with_ee = df_ee.loc[df_ee["catalog"] == "BATSE", "name"].values

# set EE flag to True for BATSE GRBs with EE
df_batse.loc[df_batse["name"].isin(batse_grbs_with_ee), "ee"] = True

# how many BATSE GRBs with EE?
df_batse["ee"].value_counts()
# Out:
# False    2666
# True       36
# Name: ee, dtype: int64

# %% [markdown]
# Set *redshift* and *luminosity* values

# %%
# add missing columns
df_batse["redshift"] = np.nan
df_batse["luminosity"] = np.nan
# fill missing values
for triggerr_num, row in df_batse_redshift.iterrows():
    # make sure that GRB is in BATSE catalog
    assert (
        triggerr_num in df_batse.index
    ), "Could not find GRB in BATSE catalog for {}".format(triggerr_num)

    # get t90 from BATSE redshift catalog
    t90_1 = row["t90"]
    # get t90 from original BATSE
    t90_2 = df_batse.loc[triggerr_num, "t90"]

    # check if they are close to each other
    assert np.isclose(
        t90_1, t90_2, rtol=1e-2
    ), "t90 values are not close to each other for {}".format(triggerr_num)

    # fill redshift
    df_batse.loc[triggerr_num, "redshift"] = row["z"]
    # fill luminosity
    df_batse.loc[triggerr_num, "luminosity"] = row["L4pi"]

# %% [markdown]
# Calculate features

# %%
# calculate intrinsic t90
df_batse["t90_intrinsic"] = df_batse["t90"] / (df_batse["redshift"] + 1)
# take log of intrinsic t90
df_batse["lgT90i"] = df_batse["t90_intrinsic"].apply(np.log10)
# take log of t90
df_batse["lgT90"] = df_batse["t90"].apply(np.log10)

# calculate hardness
df_batse["hardness"] = df_batse["fluence_3"] / df_batse["fluence_1"]
# take log of hardness
df_batse["lgHrd"] = df_batse["hardness"].apply(np.log10)

# take log of luminosity
df_batse["lgLum"] = df_batse["luminosity"].apply(np.log10)

# %% [markdown]
# Save dataset

# %%
# save BATSE catalog
path_data_batse = os.path.join(env.DIR_DATASETS, "batse.xlsx")
df_batse.to_excel(
    path_data_batse, sheet_name="data", freeze_panes=(1, 0), engine="xlsxwriter"
)

# %% [markdown]
# ## FERMI

# %% [markdown]
# Load FERMI catalog

# %%
# load fermi catalog
path_cat_fermi = os.path.join(env.DIR_CATALOGS, "fermi_catalog.xlsx")
df_fermi = pd.read_excel(path_cat_fermi, sheet_name="fermigbrst")

# show random rows
df_fermi.sample(5)
# Out:
#               name       ra     dec  trigger_time     t90       fluence  \
# 2519  GRB171212222   61.490  24.220  58099.222390  19.968  2.873500e-06
# 627   GRB120919309  214.768 -45.564  56189.308819  21.248  1.678000e-05
# 1808  GRB140724533  314.730  -1.850  56862.533206   0.896  1.269400e-07
# 1207  GRB131119781   47.960 -24.010  56615.781110  34.816  1.848700e-06
# 606   GRB100718160  121.830 -46.180  55395.159833  32.641  2.747200e-06
#
#       flux_1024  flux_1024_time  flux_64       lii      bii     t50  \
# 2519     6.8823           0.320   8.7800  169.8546 -20.4485   5.632
# 627     24.5176           2.624  28.1425  318.5949  14.6258   2.816
# 1808     1.6223          -0.256   4.5660   46.9493 -28.9726   0.128
# 1207     2.2770           8.000   4.0633  215.2597 -58.2851  20.224
# 606      4.0487           3.664   6.6872  261.6109  -7.3932   8.576
#
#       fluence_batse  flux_256  flux_batse_1024  flux_batse_64  flux_batse_256  \
# 2519   1.350500e-06    7.4117           1.6119         2.6338          1.9057
# 627    9.515000e-06   27.5658          11.8929        13.7790         13.2647
# 1808   8.253700e-08    3.1034           0.5297         2.5667          1.2351
# 1207   1.111400e-06    3.3146           0.9830         1.8252          1.3904
# 606    1.592100e-06    5.8744           1.5549         2.9767          2.7037
#
#       flnc_comp_ampl  flnc_comp_epeak  flnc_comp_index
# 2519        0.014127         53.32233        -1.226308
# 627         0.024419        221.23930        -0.995339
# 1808        0.041516        155.47700        -0.185447
# 1207        0.013101         96.64230        -0.573525
# 606         0.005334        109.95890        -1.192580

# %% [markdown]
# Set EE flag

# %%
# add column for EE flag
df_fermi["ee"] = False

# get name of FERMI GRBs with EE
fermi_grbs_with_ee = df_ee.loc[df_ee["catalog"] == "FERMI", "name"].values

# set EE flag to True for FERMI GRBs with EE
df_fermi.loc[df_fermi["name"].isin(fermi_grbs_with_ee), "ee"] = True

# how many FERMI GRBs with EE?
df_fermi["ee"].value_counts()
# Out:
# False    3555
# True       14
# Name: ee, dtype: int64

# %% [markdown]
# Calculate hardness ratio

# %%
from scipy.integrate import quad

# calculate hardness
df_fermi["hardness"] = np.nan
for index, row in df_fermi.iterrows():
    epeak = row["flnc_comp_epeak"]
    alpha = row["flnc_comp_index"]
    amplitude = row["flnc_comp_ampl"]

    if np.isnan(epeak) or np.isnan(alpha) or np.isnan(amplitude):
        continue

    flux = (
        lambda energy: energy
        * amplitude
        * ((energy / 100) ** alpha)
        * np.exp((-1 * (alpha + 2) * energy / epeak))
    )

    fluence3, err = quad(flux, 100, 300)
    fluence1, err = quad(flux, 25, 50)

    # hardness
    df_fermi.loc[index, "hardness"] = fluence3 / fluence1

# %% [markdown]
# Log transform of features

# %%
df_fermi["lgT90"] = df_fermi["t90"].apply(np.log10)
df_fermi["lgHrd"] = df_fermi["hardness"].apply(np.log10)

# %% [markdown]
# Save dataset

# %%
# save FERMI catalog
path_data_fermi = os.path.join(env.DIR_DATASETS, "fermi.xlsx")
df_fermi.to_excel(
    path_data_fermi, sheet_name="data", freeze_panes=(1, 0), engine="xlsxwriter"
)

# %% [markdown]
# ## SWIFT

# %% [markdown]
# Load SWIFT Catalog

# %%
# load fermi catalog
path_cat_swift = os.path.join(env.DIR_CATALOGS, "swift_catalog.xlsx")
df_swift = pd.read_excel(path_cat_swift)

# show random rows
df_swift.sample(5)
# Out:
#            name     z z_comment         t90 t1s_best_model  t1s_pl_alpha  \
# 924  GRB110519A   NaN       NaN   27.184000            NaN      -1.93051
# 956  GRB110102A   NaN       NaN  265.915985             PL      -1.18170
# 665  GRB140331A  4.65       NaN  209.656006            NaN      -1.37838
# 635  GRB140703A  3.14       NaN   68.643997             PL      -1.17099
# 104  GRB201229A   NaN       NaN   53.248001             PL      -1.29081
#
#      t1s_pl_norm  t1s_cpl_alpha  t1s_cpl_norm  t1s_cpl_epeak  ...  \
# 924     0.031590      -1.171170      0.083310      48.388802  ...
# 956     0.066320      -1.166800      0.067323    9887.129883  ...
# 665     0.001856      -1.413460      0.001851    9999.360352  ...
# 635     0.023658      -0.518898      0.044838     137.886002  ...
# 104     0.014234      -0.635939      0.028492     116.556000  ...
#
#              flux  model_used  t100s_best_model t100s_pl_fluence_25_50_kev  \
# 924           NaN         NaN                PL               1.224779e-06
# 956           NaN         NaN                PL               3.913973e-06
# 665  1.801741e-08           P                PL               2.122432e-07
# 635  2.420305e-07           P                PL               1.049984e-06
# 104           NaN         NaN                PL               2.957551e-07
#
#     t100s_pl_fluence_100_150_kev  t100s_cpl_fluence_25_50_kev  \
# 924                 6.420780e-07                          NaN
# 956                 4.245589e-06                 3.914334e-06
# 665                 1.302458e-07                 2.273284e-07
# 635                 8.911743e-07                 1.048583e-06
# 104                 3.638499e-07                 3.340967e-07
#
#      t100s_cpl_fluence_100_150_kev  t100s_pl_hardness  t100s_cpl_hardness  \
# 924                            NaN           0.524240                 NaN
# 956                   4.242264e-06           1.084726            1.083777
# 665                   7.917604e-08           0.613663            0.348289
# 635                   8.967527e-07           0.848750            0.855204
# 104                   2.175515e-07           1.230241            0.651163
#
#      hardness_ratio
# 924        0.524240
# 956        1.084726
# 665        0.613663
# 635        0.848750
# 104        1.230241
#
# [5 rows x 22 columns]

# %% [markdown]
# Set EE flag

# %%
# add column for EE flag
df_swift["ee"] = False

# get name of FERMI GRBs with EE
swift_grbs_with_ee = df_ee.loc[df_ee["catalog"] == "SWIFT", "name"].values

# set EE flag to True for SWIFT GRBs with EE
df_swift.loc[df_swift["name"].isin(swift_grbs_with_ee), "ee"] = True

# how many SWIFT GRBs with EE?
df_swift["ee"].value_counts()
# Out:
# False    1509
# True       16
# Name: ee, dtype: int64

# %%
df_swift
# Out:
#             name   z z_comment        t90 t1s_best_model  t1s_pl_alpha  \
# 0     GRB220715B NaN       NaN  40.408001            NaN      -0.78456
# 1     GRB220714B NaN       NaN  49.040001             PL      -1.64781
# 2     GRB220711B NaN       NaN  87.056000            NaN      -1.43626
# 3     GRB220708A NaN       NaN   4.000000             PL      -1.91564
# 4     GRB220706A NaN       NaN  85.996002             PL      -1.63229
# ...          ...  ..       ...        ...            ...           ...
# 1520   GRB041220 NaN       NaN   5.584000             PL      -1.31802
# 1521  GRB041219C NaN       NaN  10.000000             PL      -1.70236
# 1522  GRB041219B NaN       NaN   9.856000             PL      -1.34096
# 1523  GRB041219A NaN       NaN        NaN            NaN           NaN
# 1524   GRB041217 NaN       NaN   5.668000             PL      -1.41557
#
#       t1s_pl_norm  t1s_cpl_alpha  t1s_cpl_norm  t1s_cpl_epeak  ...  \
# 0        0.011339      -0.794540      0.011458    9999.360352  ...
# 1        0.029445      -1.448870      0.037503     131.455994  ...
# 2        0.024784       0.162297      0.137160      76.114601  ...
# 3        0.004836      -1.925260      0.004807    9995.040039  ...
# 4        0.006975      -1.643620      0.006933    9999.360352  ...
# ...           ...            ...           ...            ...  ...
# 1520     0.014645      -1.106840      0.018479     227.095993  ...
# 1521     0.017536      -1.275860      0.028918      85.261497  ...
# 1522     0.011391      -0.633827      0.025028     101.986000  ...
# 1523          NaN            NaN           NaN            NaN  ...
# 1524     0.056131      -0.829910      0.108141     105.275002  ...
#
#       model_used  t100s_best_model  t100s_pl_fluence_25_50_kev  \
# 0            NaN               NaN                2.745653e-07
# 1            NaN                PL                1.304739e-06
# 2            NaN                PL                1.585870e-06
# 3            NaN                PL                3.786866e-08
# 4            NaN                PL                3.715433e-07
# ...          ...               ...                         ...
# 1520         NaN                PL                9.797765e-08
# 1521         NaN                PL                3.452719e-07
# 1522         NaN                PL                8.485209e-08
# 1523         NaN               NaN                         NaN
# 1524         NaN               NaN                6.802847e-07
#
#      t100s_pl_fluence_100_150_kev t100s_cpl_fluence_25_50_kev  \
# 0                    3.548589e-07                2.841552e-07
# 1                    8.542476e-07                1.301649e-06
# 2                    1.284126e-06                1.624006e-06
# 3                    1.671822e-08                4.478472e-08
# 4                    2.936091e-07                3.685780e-07
# ...                           ...                         ...
# 1520                 8.605123e-08                9.951924e-08
# 1521                 2.003278e-07                         NaN
# 1522                 4.795263e-08                8.094358e-08
# 1523                          NaN                         NaN
# 1524                 7.807119e-07                7.205442e-07
#
#       t100s_cpl_fluence_100_150_kev  t100s_pl_hardness  t100s_cpl_hardness  \
# 0                      3.089055e-07           1.292439            1.087101
# 1                      8.842270e-07           0.654727            0.679313
# 2                      1.146457e-06           0.809730            0.705944
# 3                      4.349708e-09           0.441479            0.097125
# 4                      3.140360e-07           0.790242            0.852020
# ...                             ...                ...                 ...
# 1520                   8.014509e-08           0.878274            0.805323
# 1521                            NaN           0.580203                 NaN
# 1522                   3.807786e-08           0.565132            0.470425
# 1523                            NaN                NaN                 NaN
# 1524                   6.100995e-07           1.147625            0.846720
#
#       hardness_ratio     ee
# 0           1.292439  False
# 1           0.654727  False
# 2           0.809730  False
# 3           0.441479  False
# 4           0.790242  False
# ...              ...    ...
# 1520        0.878274  False
# 1521        0.580203  False
# 1522        0.565132  False
# 1523             NaN  False
# 1524        1.147625  False
#
# [1525 rows x 23 columns]

# %% [markdown]
# Set 'Magnetar' flag

# %%
# first, load magnetar catalog
path_cat_magnetar = os.path.join(env.DIR_CATALOGS, "swift_magnetars.xlsx")
df_magnetar = pd.read_excel(path_cat_magnetar, sheet_name="magnetars")

# get name of magnetars
magnetar_names = df_magnetar["name"].values

# add column for magnetar flag
df_swift["magnetar"] = False

# set magnetar flag to True for SWIFT GRBs with magnetar
df_swift.loc[df_swift["name"].isin(magnetar_names), "magnetar"] = True

# how many SWIFT GRBs with magnetar?
df_swift["magnetar"].value_counts()
# Out:
# False    1513
# True       12
# Name: magnetar, dtype: int64

# %% [markdown]
# Calculate features

# %%
# compute intrinsic
df_swift["t90_intrinsic"] = df_swift["t90"] / (df_swift["z"] + 1)

# take logs
df_swift["lgT90"] = df_swift["t90"].apply(np.log10)
# take log of intrinsic t90
df_swift["lgT90i"] = df_swift["t90_intrinsic"].apply(np.log10)
# take log of hardness
df_swift["lgHrd"] = df_swift["hardness_ratio"].apply(np.log10)
# take log of luminosity
df_swift["lgLum"] = df_swift["lum_kcorr"].apply(np.log10)

# %% [markdown]
# Save dataset

# %%
# save SWIFT catalog
path_data_swift = os.path.join(env.DIR_DATASETS, "swift.xlsx")
df_swift.to_excel(
    path_data_swift, sheet_name="data", freeze_panes=(1, 0), engine="xlsxwriter"
)
